# %%
import pandas as pd
df = pd.read_csv("../../data/processed/Online_Retail_clean.csv")

# %%
kpi_summary = pd.DataFrame({
    "metric": [
        "Total Revenue",
        "AOV",
        "Purchase Frequency"
    ],
    "value": [
        df_clean["Revenue"].sum(),
        df_clean.groupby("InvoiceNo")["Revenue"].sum().mean(),
        df_clean.groupby("CustomerID")["InvoiceNo"].nunique().mean()
    ]
})

kpi_summary.to_csv("../../data/kpi/kpi_summary.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 8
#       1 kpi_summary = pd.DataFrame({
#       2     "metric": [
#       3         "Total Revenue",
#       4         "AOV",
#       5         "Purchase Frequency"
#       6     ],
#       7     "value": [
# ----> 8         df_clean["Revenue"].sum(),
#       9         df_clean.groupby("InvoiceNo")["Revenue"].sum().mean(),
#      10         df_clean.groupby("CustomerID")["InvoiceNo"].nunique().mean()
#      11     ]
#      12 })
#      14 kpi_summary.to_csv("../../data/kpi/kpi_summary.csv", index=False)
#
# NameError: name 'df_clean' is not defined
