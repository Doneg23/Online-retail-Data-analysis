# %% [markdown]
# # Chuyển file xslx sang csv

# %%
import pandas as pd
import os

# %%
print("Current working dir:", os.getcwd())

input_path = "../../data/raw/Online_Retail.xlsx"
out_path = "../../data/converted/Online_Retail.csv"

df = pd.read_excel(input_path)

print("Raw shape:", df.shape)

os.makedirs("../../data/processed", exist_ok=True)

df.to_csv(out_path, index=False, encoding="utf-8-sig")

print("✅ Done!")
# Out:
# Current working dir: d:\Y2S2\G-contest-ftu\Previous\Online-retail-Data-analysis\src\processing
# Raw shape: (541909, 8)
# ✅ Done!
